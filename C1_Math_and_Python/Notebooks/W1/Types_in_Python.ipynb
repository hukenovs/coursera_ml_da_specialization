# %% [markdown]
# # Типы данных в Python (Версия для Python 3)

# %% [markdown]
# ## 1. Числовые

# %% [markdown]
# ### int

# %%
x = 5

# %%
print(x)
# Out:
# 5

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
a = 4 + 5
b = 4 * 5
c = 5 / 4

print(a, b, c)
# Out:
# 9 20 1.25

# %%
print(-5 / 4)
# Out:
# -1.25

# %%
print(-(5 / 4))
# Out:
# -1.25

# %% [markdown]
# ### long

# %%
x = 5 * 1000000 * 1000000 * 1000000 * 1000000 + 1
print(x)
print(type(x))
# Out:
# 5000000000000000000000001
# <class 'int'>

# %%
y = 5
print(type(y))
y = x
print(type(y))
# Out:
# <class 'int'>
# <class 'int'>

# %% [markdown]
# ### float

# %%
y = 5.7

# %%
print(y)
print(type(y))
# Out:
# 5.7
# <class 'float'>

# %%
a = 4.2 + 5.1
b = 4.2 * 5.1
c = 5.0 / 4.0

print(a, b, c)
# Out:
# 9.3 21.419999999999998 1.25

# %%
a = 5
b = 4
print(float(a) / float(b))
# Out:
# 1.25

# %%
print(5.0 / 4)
print(5 / 4.0)
# Out:
# 1.25
# 1.25

# %%
print(float(a) / b)
# Out:
# 1.25

# %% [markdown]
# ### bool

# %%
a = True
b = False

print(a)
print(type(a))

print(b)
print(type(b))
# Out:
# True
# <class 'bool'>
# False
# <class 'bool'>

# %%
print(a + b)
print(a + a)
print(b + b)
# Out:
# 1
# 2
# 0

# %%
print(int(a), int(b))
# Out:
# 1 0

# %%
print(True and False)
print(True and True)
print(False and False)
# Out:
# False
# True
# False

# %%
print(True or False)
print(True or True)
print(False or False)
# Out:
# True
# True
# False

# %% [markdown]
# ## 2. None

# %%
z = None
print(z)
print(type(z))
# Out:
# None
# <class 'NoneType'>

# %%
print(int(z))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-caf6459d7a1e> in <module>()
# ----> 1 print(int(z))
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %% [markdown]
# ## 3. Строковые

# %% [markdown]
# ### str

# %%
x = "abc"
print(x)
print(type(x))
# Out:
# abc
# <class 'str'>

# %%
a = 'Ivan'
b = "Ivanov"
s = a + " " + b
print(s)
# Out:
# Ivan Ivanov

# %%
print(a.upper())
print(a.lower())
# Out:
# IVAN
# ivan

# %%
print(len(a))
# Out:
# 4

# %%
print(bool(a))
print(bool(""))
# Out:
# True
# False

# %%
print(int(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-c783ea792008> in <module>()
# ----> 1 print(int(a))
#
# ValueError: invalid literal for int() with base 10: 'Ivan'

# %%
print(a)
print(a[0])
print(a[1])
print(a[0:3])
# Out:
# Ivan
# I
# v
# Iva

# %%
print(a[0:4:2])
# Out:
# Ia

# %% [markdown]
# ### unicode

# %%
x = u"abc"
print(x)
print(type(x))
# Out:
# abc
# <class 'str'>

# %%
x = u'Элеонора Михайловна'
print(x, type(x))
y = x.encode('utf-8')
print(y, type(y))
z = y.decode('utf-8')
print(z, type(z))
q = y.decode('cp1251')
print(q, type(q))
# Out:
# Элеонора Михайловна <class 'str'>
# b'\xd0\xad\xd0\xbb\xd0\xb5\xd0\xbe\xd0\xbd\xd0\xbe\xd1\x80\xd0\xb0 \xd0\x9c\xd0\xb8\xd1\x85\xd0\xb0\xd0\xb9\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xbd\xd0\xb0' <class 'bytes'>
# Элеонора Михайловна <class 'str'>
# Р­Р»РµРѕРЅРѕСЂР° РњРёС…Р°Р№Р»РѕРІРЅР° <class 'str'>

# %%
1
# Out:
# 1

# %%
x = u'Элеонора Михайловна'
print(x, type(x))
y = x.encode('utf-8')
print(y, type(y))
z = y.decode('utf-8')
print(z, type(z))
q = y.decode('cp1251')
print(q, type(q))
# Out:
# Элеонора Михайловна <class 'str'>
# b'\xd0\xad\xd0\xbb\xd0\xb5\xd0\xbe\xd0\xbd\xd0\xbe\xd1\x80\xd0\xb0 \xd0\x9c\xd0\xb8\xd1\x85\xd0\xb0\xd0\xb9\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xbd\xd0\xb0' <class 'bytes'>
# Элеонора Михайловна <class 'str'>
# Р­Р»РµРѕРЅРѕСЂР° РњРёС…Р°Р№Р»РѕРІРЅР° <class 'str'>

# %%
print(str(x))
# Out:
# Элеонора Михайловна

# %%
print(y[1:])
print(len(y), type(y))
print(len(x), type(x))
# Out:
# b'\xad\xd0\xbb\xd0\xb5\xd0\xbe\xd0\xbd\xd0\xbe\xd1\x80\xd0\xb0 \xd0\x9c\xd0\xb8\xd1\x85\xd0\xb0\xd0\xb9\xd0\xbb\xd0\xbe\xd0\xb2\xd0\xbd\xd0\xb0'
# 37 <class 'bytes'>
# 19 <class 'str'>

# %%
y = u'Иван Иванович'.encode('utf-8')
print(y.decode('utf-8'))
# Out:
# Иван Иванович

# %%
print(y.decode('cp1251'))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-117-1ab2d520e52d> in <module>()
# ----> 1 print(y.decode('cp1251'))
#
# ~\AppData\Local\conda\conda\envs\ml35\lib\encodings\cp1251.py in decode(self, input, errors)
#      13
#      14     def decode(self,input,errors='strict'):
# ---> 15         return codecs.charmap_decode(input,errors,decoding_table)
#      16
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x98 in position 1: character maps to <undefined>

# %%
splitted_line = "Ivanov Ivan Ivanovich".split(' ')
print(splitted_line)
# Out:
# ['Ivanov', 'Ivan', 'Ivanovich']

# %%
print(type(splitted_line))
# Out:
# <class 'list'>

# %%
print("Иванов Иван Иванович".split(" "))
# Out:
# ['Иванов', 'Иван', 'Иванович']

# %%
print("\x98")
# Out:
# 

# %%
print(u"Иванов Иван Иванович".split(" "))
# Out:
# ['Иванов', 'Иван', 'Иванович']

# %% [markdown]
# ## 3. Массивы

# %% [markdown]
# ### list

# %%
saled_goods_count = [33450, 34010, 33990, 33200]
print(saled_goods_count)
print(type(saled_goods_count))
# Out:
# [33450, 34010, 33990, 33200]
# <class 'list'>

# %%
income = [u'Высокий', u'Средний', u'Высокий']
names = [u'Элеонора Михайловна', u'Иван Иванович', u'Михаил Абрамович']

print(income)
print(names)
# Out:
# ['Высокий', 'Средний', 'Высокий']
# ['Элеонора Михайловна', 'Иван Иванович', 'Михаил Абрамович']

# %%
print ("---".join(income))
# Out:
# Высокий---Средний---Высокий

# %%
features = ['Ivan Ivanovich', 'Medium', 500000, 12, True]
print (features)
# Out:
# ['Ivan Ivanovich', 'Medium', 500000, 12, True]

# %%
print(features[0])
print(features[1])
print(features[3])
# Out:
# Ivan Ivanovich
# Medium
# 12

# %%
print(features[0:5])
# Out:
# ['Ivan Ivanovich', 'Medium', 500000, 12, True]

# %%
print(features[:5])
# Out:
# ['Ivan Ivanovich', 'Medium', 500000, 12, True]

# %%
print(features[1:])
# Out:
# ['Medium', 500000, 12, True]

# %%
print(features[2:5])
# Out:
# [500000, 12, True]

# %%
print(features[:-1])
# Out:
# ['Ivan Ivanovich', 'Medium', 500000, 12]

# %%
features.append('One more element in list')
print(features)
# Out:
# ['Ivan Ivanovich', 'Medium', 500000, 12, True, 'One more element in list']

# %%
del features[-2]

# %%
print(features)
# Out:
# ['Ivan Ivanovich', 'Medium', 500000, 12, 'One more element in list']

# %% [markdown]
# ### tuple

# %%
features_tuple = ('Ivan Ivanovich', 'Medium', 500000, 12, True)
print(type(features_tuple))
# Out:
# <class 'tuple'>

# %%
features_tuple[2:5]
# Out:
# (500000, 12, True)

# %%
features_tuple.append('one more element')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-f44ce76755af> in <module>()
# ----> 1 features_tuple.append('one more element')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ## 4. Множества и словари

# %% [markdown]
# ### set

# %%
names = {'Ivan', 'Petr', 'Konstantin'}

# %%
print(type(names))
# Out:
# <class 'set'>

# %%
print('Ivan' in names)
# Out:
# True

# %%
print('Mikhail' in names)
# Out:
# False

# %%
names.add('Mikhail')
print(names)
# Out:
# {'Konstantin', 'Ivan', 'Mikhail', 'Petr'}

# %%
names.add('Mikhail')
print(names)
# Out:
# {'Konstantin', 'Ivan', 'Mikhail', 'Petr'}

# %%
names.remove('Mikhail')
print(names)
# Out:
# {'Konstantin', 'Ivan', 'Petr'}

# %%
names.add(['Vladimir', 'Vladimirovich'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-3de23a3ba581> in <module>()
# ----> 1 names.add(['Vladimir', 'Vladimirovich'])
#
# TypeError: unhashable type: 'list'

# %%
names.add(('Vladimir', 'Vladimirovich'))
print(names)
# Out:
# {'Konstantin', 'Ivan', ('Vladimir', 'Vladimirovich'), 'Petr'}

# %%
a = range(10000)
b = range(10000)
b = set(b)

# %%
print(a[:5])
print(a[-5:])
# Out:
# range(0, 5)
# range(9995, 10000)

# %%
# %%time
print(9999 in a)
# Out:
# True
# Wall time: 0 ns

# %%
# %%time
print(9999 in b)
# Out:
# True
# Wall time: 0 ns

# %% [markdown]
# ### dict

# %%
words_frequencies = dict()
words_frequencies['I'] = 1
words_frequencies['am'] = 1
words_frequencies['I'] += 1

print(words_frequencies)
# Out:
# {'I': 2, 'am': 1}

# %%
print(words_frequencies['I'])
# Out:
# 2

# %%
words_frequencies = {'I': 2, 'am': 1}
print(words_frequencies)
# Out:
# {'I': 2, 'am': 1}

# %%
yet_another_dict = {'abc': 3.4, 5: 7.8, u'123': None}
print(yet_another_dict)
# Out:
# {'abc': 3.4, '123': None, 5: 7.8}

# %%
yet_another_dict[(1,2,5)] = [4, 5, 7]
print(yet_another_dict)
# Out:
# {'abc': 3.4, '123': None, 5: 7.8, (1, 2, 5): [4, 5, 7]}

# %%
yet_another_dict[[1,2,7]] = [4, 5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-75dfec87d1d3> in <module>()
# ----> 1 yet_another_dict[[1,2,7]] = [4, 5]
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ## Где еще можно познакомиться с Python

# %% [markdown]
# * https://www.coursera.org/courses?query=Python
# * https://www.codeacademy.com
# * http://www.pythontutor.ru
# * http://www.learnpythonthehardway.org
# * http://snakify.org
# * https://www.checkio.org
